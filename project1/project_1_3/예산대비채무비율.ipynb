# %%
import pandas as pd

# %%
pd.read_csv('C:/Users/jangd/OneDrive/사진/문서/GitHub/git_hub_0420/python/project/2011_예산대비채무비율.csv',encoding='utf8')
# Out:
#     Unnamed: 0 Unnamed: 1  Unnamed: 2            단위 : 백만원, %
# 0         자치단체  채무잔액\n(A)  최종예산액\n(B)  예산대비채무 비율 \n(A/B)x100
# 1         서울본청  5,505,960  28,594,041                  19.26
# 2        서울종로구          0     465,677                     .0
# 3         서울중구          0     394,569                     .0
# 4        서울용산구          0     366,162                     .0
# ..         ...        ...         ...                    ...
# 239      경남산청군        192     385,992                    .05
# 240      경남함양군          0     371,915                     .0
# 241      경남거창군          0     502,920                     .0
# 242      경남합천군          0     515,167                     .0
# 243       제주본청    573,533   4,786,101                  11.98
#
# [244 rows x 4 columns]

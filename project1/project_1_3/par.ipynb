# %%
import pandas as pd

# %%
a=pd.read_excel('C:/Users/jangd/OneDrive/사진/문서/GitHub/git_hub_0420/python/2022_통합재정수지비율(당초).xls')
a
# Out:
#       자치단체  세입 \n(A)  지출 \n(B)  순융자\n(C)  통합재정규모\n(D)  \
# 0     서울본청  34355909  34891881    570833     35462714
# 1    서울종로구    465430    464684      1723       466406
# 2     서울중구    487840    575990       115       576105
# 3    서울용산구    552008    576989       -19       576970
# 4    서울성동구    615714    642230      1353       643582
# ..     ...       ...       ...       ...          ...
# 238  경남산청군    523337    578650      5778       584428
# 239  경남함양군    484643    535561      3369       538930
# 240  경남거창군    586743    652905      1906       654811
# 241  경남합천군    647806    632584      1420       634004
# 242   제주본청   5591915   5951732      7306      5959037
#
#      통합재정수지비율[당초] \n((A-(B+C))/D)x100
# 0                               -3.12
# 1                               -0.21
# 2                              -15.32
# 3                               -4.33
# 4                               -4.33
# ..                                ...
# 238                            -10.45
# ...

# %%
import pandas as pd

# %%
a=pd.read_csv('./input1.csv',encoding='cp949')

# %%
a.describe()
# Out:
#           통합재정수지비율   예산대비채무 비율         재정자립도        지방세징수액          증감율  \
# count  1455.000000  1455.000000  1455.000000  1.455000e+03  1455.000000
# mean      2.515491     2.199629    20.025354  3.502453e+05     4.393175
# std       7.961390     4.260467    12.530943  1.504490e+06     4.097529
# min     -31.050000     0.000000     3.130000  3.202000e+03   -29.120000
# 25%      -3.115000     0.000000    10.035000  2.809750e+04     2.470000
# 50%       3.110000     0.000000    16.770000  6.728500e+04     3.780000
# 75%       7.190000     2.540000    27.260000  1.548275e+05     5.460000
# max      39.740000    33.400000    77.690000  2.339302e+07    75.330000
#
#          자본대비 부채비율
# count  1455.000000
# mean     37.195196
# std     101.329323
# min   -1646.160000
# 25%       0.000000
# 50%       1.630000
# 75%      34.530000
# max    1355.120000

# %%
a.rename(columns={'예산대비채무 비율 ':"예산대비채무비율",'통합재정수지비율':"통합재정수지적자비율"},inplace=True)

# %%
a['통합재정수지적자비율']=-a['통합재정수지적자비율']

# %%
a
# Out:
#        자치단체  통합재정수지적자비율  예산대비채무비율  재정자립도    지방세징수액   증감율  자본대비 부채비율
# 0      서울본청        4.79     19.26  77.69  15624421  0.72     105.05
# 1     서울종로구       11.68      0.00  42.53     58807  2.25      97.93
# 2      서울중구       16.59      0.00  55.85     93456  1.94     250.19
# 3     서울용산구        8.63      0.00  36.64     53233  1.75     103.72
# 4     서울성동구        7.27      0.00  30.89     37058  0.66     220.27
# ...     ...         ...       ...    ...       ...   ...        ...
# 1450  경남산청군        6.49      0.00   8.13     26279  2.79       0.00
# 1451  경남함양군        6.12      1.37   8.86     28654  2.58       0.00
# 1452  경남거창군        4.47      0.00   7.71     34280  2.38      10.17
# 1453  경남합천군        0.79      0.00   6.57     27808 -1.06       1.65
# 1454   제주본청        6.06     10.07  30.98   1601823  3.51      30.09
#
# [1455 rows x 7 columns]

# %%
a.loc[a['통합재정수지적자비율']>25]
# Out:
#      자치단체  통합재정수지적자비율  예산대비채무비율  재정자립도  지방세징수액   증감율  자본대비 부채비율
# 84  경기성남시       31.05      4.21  53.61  794431  0.49       3.05

# %%
import matplotlib.pyplot as plt

plt.hist(a['통합재정수지적자비율'])
plt.show()

# %%
a.loc[a['통합재정수지적자비율']>0]
# Out:
#        자치단체  통합재정수지적자비율  예산대비채무비율  재정자립도    지방세징수액   증감율  자본대비 부채비율
# 0      서울본청        4.79     19.26  77.69  15624421  0.72     105.05
# 1     서울종로구       11.68      0.00  42.53     58807  2.25      97.93
# 2      서울중구       16.59      0.00  55.85     93456  1.94     250.19
# 3     서울용산구        8.63      0.00  36.64     53233  1.75     103.72
# 4     서울성동구        7.27      0.00  30.89     37058  0.66     220.27
# ...     ...         ...       ...    ...       ...   ...        ...
# 1450  경남산청군        6.49      0.00   8.13     26279  2.79       0.00
# 1451  경남함양군        6.12      1.37   8.86     28654  2.58       0.00
# 1452  경남거창군        4.47      0.00   7.71     34280  2.38      10.17
# 1453  경남합천군        0.79      0.00   6.57     27808 -1.06       1.65
# 1454   제주본청        6.06     10.07  30.98   1601823  3.51      30.09
#
# [511 rows x 7 columns]

# %%
a.loc[a['통합재정수지적자비율']>0].describe()
# Out:
#        통합재정수지적자비율    예산대비채무비율       재정자립도        지방세징수액         증감율  \
# count  511.000000  511.000000  511.000000  5.110000e+02  511.000000
# mean     5.840470    3.158200   20.884697  4.808177e+05    3.560157
# std      4.365977    4.964547   13.263912  1.875995e+06    4.050424
# min      0.010000    0.000000    4.290000  3.202000e+03  -29.120000
# 25%      2.695000    0.000000   10.065000  2.702350e+04    1.795000
# 50%      5.040000    0.760000   16.970000  6.382800e+04    3.180000
# 75%      7.920000    4.525000   28.410000  2.009810e+05    4.600000
# max     31.050000   33.400000   77.690000  2.339302e+07   49.950000
#
#          자본대비 부채비율
# count   511.000000
# mean     33.465695
# std     110.743331
# min   -1646.160000
# 25%       0.000000
# 50%       2.180000
# 75%      30.015000
# max     781.530000

# %%
import numpy as np

a['통합재정수지적자비율평가점수'] = np.random.randn(1455)

for i in range(1455):
    if a['통합재정수지적자비율'][i]<0: # 0이하는 미만은 0점
        a['통합재정수지적자비율평가점수'][i]=0
    elif a['통합재정수지적자비율'][i]>=0 and a['통합재정수지적자비율'][i]<2.69:  # 0~25% = 2.69까지 1점
        a['통합재정수지적자비율평가점수'][i]=1
    elif a['통합재정수지적자비율'][i]>=2.69 and a['통합재정수지적자비율'][i]<5.04: # 25%~50%까지 2점
        a['통합재정수지적자비율평가점수'][i]=2
    elif a['통합재정수지적자비율'][i]>=5.04 and a['통합재정수지적자비율'][i]<7.92:  # 50%~75% 3점
        a['통합재정수지적자비율평가점수'][i]=3
    elif a['통합재정수지적자비율'][i]>=7.92 and a['통합재정수지적자비율'][i]<25: #75%~주의기준 4점
        a['통합재정수지적자비율평가점수'][i]=4
    else:
        a['통합재정수지적자비율평가점수'][i]=5   #주의기준 넘어서면 5점
# Out:
# c:\Users\jangd\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# c:\Users\jangd\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# c:\Users\jangd\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
a
# Out:
#        자치단체  통합재정수지적자비율  예산대비채무비율  재정자립도    지방세징수액   증감율  자본대비 부채비율  \
# 0      서울본청        4.79     19.26  77.69  15624421  0.72     105.05
# 1     서울종로구       11.68      0.00  42.53     58807  2.25      97.93
# 2      서울중구       16.59      0.00  55.85     93456  1.94     250.19
# 3     서울용산구        8.63      0.00  36.64     53233  1.75     103.72
# 4     서울성동구        7.27      0.00  30.89     37058  0.66     220.27
# ...     ...         ...       ...    ...       ...   ...        ...
# 1450  경남산청군        6.49      0.00   8.13     26279  2.79       0.00
# 1451  경남함양군        6.12      1.37   8.86     28654  2.58       0.00
# 1452  경남거창군        4.47      0.00   7.71     34280  2.38      10.17
# 1453  경남합천군        0.79      0.00   6.57     27808 -1.06       1.65
# 1454   제주본청        6.06     10.07  30.98   1601823  3.51      30.09
#
#       통합재정수지적자비율평가점수
# 0                2.0
# 1                4.0
# 2                4.0
# 3                4.0
# 4                3.0
# ...

# %%
plt.hist(a['예산대비채무비율'])
plt.show()

# %%
a['예산대비채무비율'].describe()
# Out:
# count    1455.000000
# mean        2.199629
# std         4.260467
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.540000
# max        33.400000
# Name: 예산대비채무비율, dtype: float64

# %%
a.loc[a['예산대비채무비율']>=2.54].describe()
# Out:
#        통합재정수지적자비율    예산대비채무비율       재정자립도        지방세징수액         증감율  \
# count  365.000000  365.000000  365.000000  3.650000e+02  365.000000
# mean    -0.017863    7.831534   26.708630  1.101730e+06    4.604082
# std      8.088836    5.375259   14.494367  2.867673e+06    5.800850
# min    -28.920000    2.540000    4.570000  3.202000e+03   -5.230000
# 25%     -4.830000    3.790000   15.370000  5.272200e+04    2.220000
# 50%      0.190000    5.890000   24.460000  1.852460e+05    3.650000
# 75%      5.550000   10.390000   36.620000  1.034819e+06    5.360000
# max     31.050000   33.400000   77.690000  2.339302e+07   75.330000
#
#          자본대비 부채비율  통합재정수지적자비율평가점수
# count   365.000000      365.000000
# mean     34.944384        1.320548
# std     112.634200        1.505937
# min   -1646.160000        0.000000
# 25%       0.790000        0.000000
# 50%      15.090000        1.000000
# 75%      36.910000        3.000000
# max     468.460000        5.000000

# %%
a['예산대비채무비율평가점수'] = np.random.randn(1455)

for i in range(1455):
    if a['예산대비채무비율'][i]<2.54: # 75% 이하인 2.54미만은 0점
        a['예산대비채무비율평가점수'][i]=0
    elif a['예산대비채무비율'][i]>=2.54 and a['예산대비채무비율'][i]<3.79:  # 2.54~ 25%인 3.79
        a['예산대비채무비율평가점수'][i]=1
    elif a['예산대비채무비율'][i]>=3.79 and a['예산대비채무비율'][i]<5.89: # 25%~50%
        a['예산대비채무비율평가점수'][i]=2
    elif a['예산대비채무비율'][i]>=5.89 and a['예산대비채무비율'][i]<10.39:  # 50%~75% 3점
        a['예산대비채무비율평가점수'][i]=3
    elif a['예산대비채무비율'][i]>=7.83 and a['예산대비채무비율'][i]<12: #75%~주의기준 4점
        a['예산대비채무비율평가점수'][i]=4
    else:
        a['예산대비채무비율평가점수'][i]=5   #주의기준 넘어서면 5점
# Out:
# c:\Users\jangd\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# c:\Users\jangd\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# c:\Users\jangd\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
a
# Out:
#        자치단체  통합재정수지적자비율  예산대비채무비율  재정자립도    지방세징수액   증감율  자본대비 부채비율  \
# 0      서울본청        4.79     19.26  77.69  15624421  0.72     105.05
# 1     서울종로구       11.68      0.00  42.53     58807  2.25      97.93
# 2      서울중구       16.59      0.00  55.85     93456  1.94     250.19
# 3     서울용산구        8.63      0.00  36.64     53233  1.75     103.72
# 4     서울성동구        7.27      0.00  30.89     37058  0.66     220.27
# ...     ...         ...       ...    ...       ...   ...        ...
# 1450  경남산청군        6.49      0.00   8.13     26279  2.79       0.00
# 1451  경남함양군        6.12      1.37   8.86     28654  2.58       0.00
# 1452  경남거창군        4.47      0.00   7.71     34280  2.38      10.17
# 1453  경남합천군        0.79      0.00   6.57     27808 -1.06       1.65
# 1454   제주본청        6.06     10.07  30.98   1601823  3.51      30.09
#
#       통합재정수지적자비율평가점수  예산대비채무비율평가점수
# 0                2.0           5.0
# 1                4.0           0.0
# 2                4.0           0.0
# ...

# %%
plt.hist(a['재정자립도'])
plt.show()

# %%
a['재정자립도'].describe()
# Out:
# count    1455.000000
# mean       20.025354
# std        12.530943
# min         3.130000
# 25%        10.035000
# 50%        16.770000
# 75%        27.260000
# max        77.690000
# Name: 재정자립도, dtype: float64

# %%
a['재정자립도비율평가점수'] = np.random.randn(1455)

for i in range(1455):
    if a['재정자립도'][i]<10.035000: # 25% 이하인 10.035미만은 0점
        a['재정자립도비율평가점수'][i]=5
    elif a['재정자립도'][i]>=10.035000 and a['재정자립도'][i]<16.770000:  # 25%~50인 3.79
        a['재정자립도비율평가점수'][i]=4
    elif a['재정자립도'][i]>=16.770000and a['재정자립도'][i]<20.025354: # 25%~평균
        a['재정자립도비율평가점수'][i]=3
    elif a['재정자립도'][i]>=20.025354 and a['재정자립도'][i]<27.260000:  # 평균~75%
        a['재정자립도비율평가점수'][i]=2
    elif a['재정자립도'][i]>=27.260000 and a['재정자립도'][i]<50: #75%~50으로 놓은 이유는 서울 평균이 50임
        a['재정자립도비율평가점수'][i]=1
    else:
        a['재정자립도비율평가점수'][i]=0
# Out:
# c:\Users\jangd\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# c:\Users\jangd\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# c:\Users\jangd\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
a
# Out:
#        자치단체  통합재정수지적자비율  예산대비채무비율  재정자립도    지방세징수액   증감율  자본대비 부채비율  \
# 0      서울본청        4.79     19.26  77.69  15624421  0.72     105.05
# 1     서울종로구       11.68      0.00  42.53     58807  2.25      97.93
# 2      서울중구       16.59      0.00  55.85     93456  1.94     250.19
# 3     서울용산구        8.63      0.00  36.64     53233  1.75     103.72
# 4     서울성동구        7.27      0.00  30.89     37058  0.66     220.27
# ...     ...         ...       ...    ...       ...   ...        ...
# 1450  경남산청군        6.49      0.00   8.13     26279  2.79       0.00
# 1451  경남함양군        6.12      1.37   8.86     28654  2.58       0.00
# 1452  경남거창군        4.47      0.00   7.71     34280  2.38      10.17
# 1453  경남합천군        0.79      0.00   6.57     27808 -1.06       1.65
# 1454   제주본청        6.06     10.07  30.98   1601823  3.51      30.09
#
#       통합재정수지적자비율평가점수  예산대비채무비율평가점수  재정자립도비율평가점수
# 0                2.0           5.0          0.0
# 1                4.0           0.0          1.0
# ...

# %%
a.drop(['지방세징수액','증감율','자본대비 부채비율'],axis=1,inplace=True)

# %%
a
# Out:
#        자치단체  통합재정수지적자비율  예산대비채무비율  재정자립도  통합재정수지적자비율평가점수  예산대비채무비율평가점수  \
# 0      서울본청        4.79     19.26  77.69             2.0           5.0
# 1     서울종로구       11.68      0.00  42.53             4.0           0.0
# 2      서울중구       16.59      0.00  55.85             4.0           0.0
# 3     서울용산구        8.63      0.00  36.64             4.0           0.0
# 4     서울성동구        7.27      0.00  30.89             3.0           0.0
# ...     ...         ...       ...    ...             ...           ...
# 1450  경남산청군        6.49      0.00   8.13             3.0           0.0
# 1451  경남함양군        6.12      1.37   8.86             3.0           0.0
# 1452  경남거창군        4.47      0.00   7.71             2.0           0.0
# 1453  경남합천군        0.79      0.00   6.57             1.0           0.0
# 1454   제주본청        6.06     10.07  30.98             3.0           3.0
#
#       재정자립도비율평가점수
# 0             0.0
# 1             1.0
# 2             0.0
# 3             1.0
# ...

# %%
a['총합'] = np.random.randn(1455)

a['총합']=a['통합재정수지적자비율평가점수']+a['예산대비채무비율평가점수'][i]+a['재정자립도비율평가점수']

# %%
a['총합'].describe()
# Out:
# count    1455.000000
# mean        6.959450
# std         2.066735
# min         3.000000
# 25%         5.000000
# 50%         7.000000
# 75%         8.000000
# max        12.000000
# Name: 총합, dtype: float64

# %%
plt.hist(a['총합'])
plt.show()

# %%
a.set_index('자치단체',inplace=True)

# %%
a.drop(['통합재정수지적자비율평가점수','예산대비채무비율평가점수','재정자립도비율평가점수'],axis=1,inplace=True)

# %%
a
# Out:
#        통합재정수지적자비율  예산대비채무비율  재정자립도    총합
# 자치단체
# 서울본청         4.79     19.26  77.69   5.0
# 서울종로구       11.68      0.00  42.53   8.0
# 서울중구        16.59      0.00  55.85   7.0
# 서울용산구        8.63      0.00  36.64   8.0
# 서울성동구        7.27      0.00  30.89   7.0
# ...           ...       ...    ...   ...
# 경남산청군        6.49      0.00   8.13  11.0
# 경남함양군        6.12      1.37   8.86  11.0
# 경남거창군        4.47      0.00   7.71  10.0
# 경남합천군        0.79      0.00   6.57   9.0
# 제주본청         6.06     10.07  30.98   7.0
#
# [1455 rows x 4 columns]

# %%
a.iloc[:,3]
# Out:
# 자치단체
# 서울본청      5.0
# 서울종로구     8.0
# 서울중구      7.0
# 서울용산구     8.0
# 서울성동구     7.0
#          ...
# 경남산청군    11.0
# 경남함양군    11.0
# 경남거창군    10.0
# 경남합천군     9.0
# 제주본청      7.0
# Name: 총합, Length: 1455, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score

# %%
x_train, x_test, y_train, y_test = train_test_split(a.iloc[:,:3], a.iloc[:,3], test_size=0.3, random_state=42)

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
pred = lr.predict(x_test)
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, pred)
print(f'mse : {mse} \nrmse : {rmse} \nr2 : {r2} \ncoef : {lr.coef_} \nintercept : {lr.intercept_}')
# Out:
# mse : 1.005096372143667
# rmse : 1.0025449476924548
# r2 : 0.7564679137587496
# coef : [ 0.14491919  0.02612915 -0.12162997]
# intercept : 9.721971611518876

# %%
# 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)
coef_ = pd.Series(lr.coef_, index=x_train.columns)
coef_sort = coef_.sort_values(ascending=False)
sns.barplot(x=coef_sort.values, y=coef_sort.index)
# Out:
# <AxesSubplot:>
